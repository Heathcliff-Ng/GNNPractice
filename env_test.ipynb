# %%
from env_test import SpatOmics_graph
from args import get_dqn_args
import os

# %%
args = get_dqn_args()

args.rs = 200
args.cell_coords_file = 'data/voronoi/UPMC_c001_v001_r001_reg001.cell_data.csv'
args.cell_types_file = 'data/voronoi/UPMC_c001_v001_r001_reg001.cell_types.csv'
args.cell_biomarker_expression_file = 'data/voronoi/UPMC_c001_v001_r001_reg001.expression.csv'
args.cell_features_file = 'data/voronoi/UPMC_c001_v001_r001_reg001.cell_features.csv'

args.fig_save_root = 'test'
os.makedirs(args.fig_save_root, exist_ok=True)

# %%
env = SpatOmics_graph(args)
env.reset()
# Out:
# /home/ww/PycharmProjects/GNNPractice/graph_build_remake.py:332: UserWarning: Cell ids in the two dataframes do not match
#   warnings.warn("Cell ids in the two dataframes do not match")
# /home/ww/PycharmProjects/GNNPractice/graph_build_remake.py:158: UserWarning: Skipping column ACQUISITION_ID as it is not numeric
#   warnings.warn("Skipping column %s as it is not numeric" % bm)
# /home/ww/PycharmProjects/GNNPractice/graph_build_remake.py:332: UserWarning: Cell ids in the two dataframes do not match
#   warnings.warn("Cell ids in the two dataframes do not match")
# Time taken to construct the graph: 0.50 seconds
# [2570.6, 898.4]

# %%
env.step(0)
# Out:
# Time taken to construct the graph: 0.43 seconds
# [2370.6, 1098.4]

# %%
env.step(4)
# Out:
# Time taken to construct the graph: 0.45 seconds
# [2570.6, 1098.4]
